# %%
import psycopg2
import pandas as pd

# %%
def create_database():
    # connect to default database
    conn = psycopg2.connect(
        host = "127.0.0.1",
        dbname = "postgres",
        user = "postgres",
        password = "password123"
    )
    conn.set_session(autocommit = True)
    cur = conn.cursor()
    # create new database
    cur.execute("DROP DATABASE IF EXISTS openflight;")
    cur.execute("CREATE DATABASE openflight;")
    # close connection to default datavase
    conn.close()
    # connect to new database 
    conn = psycopg2.connect(
        host = "127.0.0.1",
        dbname = "openflight",
        user = "postgres",
        password = "password123"
    )
    cur = conn.cursor()
    return cur, conn

# %%
# def drop_tables(cur, conn):
#     for query in drop_table_queries:
#         cur.execute(query)
#         cur.commit()

# def create_tables(cur, conn):
#     for query in create_table_queries:
#         cur.execute(query)
#         cur.commit()

# %%
airlines = pd.read_csv(r"open-flight-data\airlines.csv")
airlines = airlines.drop(columns="Alias")
# Encode active column to boolean
airlines["Active"] = airlines.Active.map({"Y": True,"N": False})

# %%
airlines.head()
# Out:
#    Airline ID                                          Name IATA ICAO
# 0          -1                                       Unknown    -  NaN  \
# 1           1                                Private flight    -  NaN
# 2           2                                   135 Airways  NaN  GNL
# 3           3                                 1Time Airline   1T  RNX
# 4           4  2 Sqn No 1 Elementary Flying Training School  NaN  WYT
#
#   Callsign         Country Active
# 0       \N              \N   True
# 1      NaN             NaN   True
# 2  GENERAL   United States  False
# 3  NEXTIME    South Africa   True
# 4      NaN  United Kingdom  False

# %%
airlines.dtypes
# Out:
# Airline ID     int64
# Name          object
# IATA          object
# ICAO          object
# Callsign      object
# Country       object
# Active        object
# dtype: object

# %%
routes = pd.read_csv(
    r"open-flight-data\routes.csv",
    usecols=[
        'Airline ID', 
        'Source airport ID',
        'Destination airport ID', 
        'Stops',
        'Equipment'
    ]
)

# %%
# Problem: have missing value in id(s) columns
# Solution: 1. drop them 2. encode them with Int dtype
routes.loc[routes["Airline ID"] == "\\N", "Airline ID"] = None
routes.loc[routes["Source airport ID"] == "\\N", "Source airport ID"] = None
routes.loc[routes["Destination airport ID"] == "\\N", "Destination airport ID"] = None

# %%
routes = routes.reset_index()

# %%
routes.head()
# Out:
#    index Airline ID Source airport ID Destination airport ID  Stops Equipment
# 0      0        410              2965                   2990      0       CR2
# 1      1        410              2966                   2990      0       CR2
# 2      2        410              2966                   2962      0       CR2
# 3      3        410              2968                   2990      0       CR2
# 4      4        410              2968                   4078      0       CR2

# %%
routes.dtypes
# Out:
# index                      int64
# Airline ID                object
# Source airport ID         object
# Destination airport ID    object
# Stops                      int64
# Equipment                 object
# dtype: object

# %%
airports = pd.read_csv(
    r"open-flight-data\airports.csv"
)
airports = airports.drop(columns=["Tz database time zone", "Type", "Source"])

# %%
airports["Timezone"] = airports["Timezone"].str.replace("\\N", "NaN").astype("float")

# %%
airports.head()
# Out:
#    Airport ID                                         Name          City
# 0           1                               Goroka Airport        Goroka  \
# 1           2                               Madang Airport        Madang
# 2           3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3           4                               Nadzab Airport        Nadzab
# 4           5  Port Moresby Jacksons International Airport  Port Moresby
#
#             Country IATA  ICAO  Latitude   Longitude  Altitude  Timezone DST
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282      10.0   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20      10.0   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388      10.0   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239      10.0   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146      10.0   U

# %% [markdown]
# #### Ingest data

# %%
cur, conn = create_database()

# %%
airline_table_create = """
CREATE TABLE IF NOT EXISTS airline(
    id INTEGER PRIMARY KEY,
    name VARCHAR,
    iata VARCHAR,
    icao VARCHAR,
    callsign VARCHAR,
    country VARCHAR,
    active BOOLEAN
);
"""
cur.execute(airline_table_create)
conn.commit()

# %%
airport_table_create = """
CREATE TABLE IF NOT EXISTS airport(
    id INTEGER PRIMARY KEY,
    name VARCHAR,
    city VARCHAR,
    country VARCHAR,
    iata VARCHAR,
    icao VARCHAR,
    lat FLOAT,
    long FLOAT,
    altitude INTEGER,
    timezone FLOAT,
    dst VARCHAR
)
"""
cur.execute(airport_table_create)
conn.commit()

# %%
route_table_create = """
CREATE TABLE IF NOT EXISTS route(
    id INTEGER PRIMARY KEY,
    airline_id INTEGER REFERENCES airline(id),
    source_airport_id INTEGER REFERENCES airport(id),
    destination_airport_id INTEGER REFERENCES airport(id),
    stops INTEGER,
    equipment VARCHAR
);
"""
cur.execute(route_table_create)
conn.commit()

# %%
airlines.loc[airlines.Active.isna(), 'Active'] = None

# %%
airline_table_insert = """
INSERT INTO airline 
VALUES (%s, %s, %s, %s, %s, %s, %s);
"""
try:
    for i, row in airlines.iterrows():
        cur.execute(airline_table_insert, list(row))
    conn.commit()
except Exception as e:
    # Roll back the transaction
    conn.rollback()
    # Log the exception
    print("Error occurred during transaction: ", e)
    print("Type of exception: ", type(e))

# %%
airport_table_insert = """
INSERT INTO airport 
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
"""
try:
    for i, row in airports.iterrows():
        cur.execute(airport_table_insert, list(row))
    conn.commit()
except Exception as e:
    # Roll back the transaction
    conn.rollback()
    # Log the exception
    print("Error occurred during transaction: ", e)

# %%
route_table_insert = """
INSERT INTO route 
VALUES (%s, %s, %s, %s, %s, %s);
"""
dropped_rows = []
for i, row in routes.iterrows():
    try:
        cur.execute(route_table_insert, list(row))
        conn.commit()
    except psycopg2.errors.ForeignKeyViolation as e:
        # Roll back the transaction
        conn.rollback()
        # Log the exception
        print("Error: ", e)
        print("Skipped no reference record:", row)
        dropped_rows.append(row)
# Drawback of sql: strict error protection (if error during transction, must be rollback)
# Out:
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7167) is not present in table "airport".
#
# Skipped no reference record: index                      170
# Airline ID                 146
# Source airport ID         3531
# Destination airport ID    7167
# Stops                        0
# Equipment                  BNI
# Name: 170, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7168) is not present in table "airport".
#
# Skipped no reference record: index                      171
# Airline ID                 146
# Source airport ID         3531
# Destination airport ID    7168
# Stops                        0
# Equipment                  BNI
# Name: 171, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7164) is not present in table "airport".
#
# Skipped no reference record: index                      173
# Airline ID                 146
# Source airport ID         3531
# Destination airport ID    7164
# Stops                        0
# Equipment                  BNI
# Name: 173, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7163) is not present in table "airport".
#
# Skipped no reference record: index                      174
# Airline ID                 146
# Source airport ID         3531
# Destination airport ID    7163
# Stops                        0
# Equipment                  BNI
# Name: 174, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7167) is not present in table "airport".
#
# Skipped no reference record: index                      175
# Airline ID                 146
# Source airport ID         7167
# Destination airport ID    7176
# Stops                        0
# Equipment                  BNI
# Name: 175, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7168) is not present in table "airport".
#
# Skipped no reference record: index                      176
# Airline ID                 146
# Source airport ID         7168
# Destination airport ID    7173
# Stops                        0
# Equipment                  BNI
# Name: 176, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7164) is not present in table "airport".
#
# Skipped no reference record: index                      178
# Airline ID                 146
# Source airport ID         7164
# Destination airport ID    7165
# Stops                        0
# Equipment                  BNI
# Name: 178, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7173) is not present in table "airport".
#
# Skipped no reference record: index                      179
# Airline ID                 146
# Source airport ID         7173
# Destination airport ID    7172
# Stops                        0
# Equipment                  BNI
# Name: 179, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7144) is not present in table "airport".
#
# Skipped no reference record: index                       270
# Airline ID                16262
# Source airport ID          7144
# Destination airport ID     7145
# Stops                         0
# Equipment                   DHP
# Name: 270, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7144) is not present in table "airport".
#
# Skipped no reference record: index                       271
# Airline ID                16262
# Source airport ID          7144
# Destination airport ID     3808
# Stops                         0
# Equipment                   DHP
# Name: 271, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7145) is not present in table "airport".
#
# Skipped no reference record: index                       272
# Airline ID                16262
# Source airport ID          7145
# Destination airport ID     7144
# Stops                         0
# Equipment                   DHP
# Name: 272, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7145) is not present in table "airport".
#
# Skipped no reference record: index                       273
# Airline ID                16262
# Source airport ID          7145
# Destination airport ID     7147
# Stops                         0
# Equipment                   DHP
# Name: 273, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7145) is not present in table "airport".
#
# Skipped no reference record: index                       274
# Airline ID                16262
# Source airport ID          7145
# Destination airport ID     3808
# Stops                         0
# Equipment                   DHP
# Name: 274, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7147) is not present in table "airport".
#
# Skipped no reference record: index                       275
# Airline ID                16262
# Source airport ID          7147
# Destination airport ID     7145
# Stops                         0
# Equipment                   DHP
# Name: 275, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7147) is not present in table "airport".
#
# Skipped no reference record: index                       276
# Airline ID                16262
# Source airport ID          7147
# Destination airport ID     3808
# Stops                         0
# Equipment                   DHP
# Name: 276, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7144) is not present in table "airport".
#
# Skipped no reference record: index                       277
# Airline ID                16262
# Source airport ID          3808
# Destination airport ID     7144
# Stops                         0
# Equipment                   DHP
# Name: 277, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7145) is not present in table "airport".
#
# Skipped no reference record: index                       278
# Airline ID                16262
# Source airport ID          3808
# Destination airport ID     7145
# Stops                         0
# Equipment                   DHP
# Name: 278, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7147) is not present in table "airport".
#
# Skipped no reference record: index                       279
# Airline ID                16262
# Source airport ID          3808
# Destination airport ID     7147
# Stops                         0
# Equipment                   DHP
# Name: 279, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                      861
# Airline ID                4608
# Source airport ID         5475
# Destination airport ID    3376
# Stops                        0
# Equipment                  319
# Name: 861, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(8858) is not present in table "airport".
#
# Skipped no reference record: index                      919
# Airline ID                4608
# Source airport ID         8858
# Destination airport ID    3369
# Stops                        0
# Equipment                  319
# Name: 919, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(8858) is not present in table "airport".
#
# Skipped no reference record: index                      925
# Airline ID                4608
# Source airport ID         3369
# Destination airport ID    8858
# Stops                        0
# Equipment                  319
# Name: 925, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                      942
# Airline ID                4608
# Source airport ID         3376
# Destination airport ID    5475
# Stops                        0
# Equipment                  319
# Name: 942, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7215) is not present in table "airport".
#
# Skipped no reference record: index                     1001
# Airline ID                None
# Source airport ID         5965
# Destination airport ID    7215
# Stops                        0
# Equipment                  PAG
# Name: 1001, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7215) is not present in table "airport".
#
# Skipped no reference record: index                     1003
# Airline ID                None
# Source airport ID         7215
# Destination airport ID    3423
# Stops                        0
# Equipment                  PAG
# Name: 1003, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7119) is not present in table "airport".
#
# Skipped no reference record: index                     1694
# Airline ID                None
# Source airport ID         3417
# Destination airport ID    7119
# Stops                        0
# Equipment                  PA2
# Name: 1694, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7119) is not present in table "airport".
#
# Skipped no reference record: index                     1698
# Airline ID                None
# Source airport ID         7119
# Destination airport ID    6712
# Stops                        0
# Equipment                  PA2
# Name: 1698, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7112) is not present in table "airport".
#
# Skipped no reference record: index                     1704
# Airline ID                None
# Source airport ID         3832
# Destination airport ID    7112
# Stops                        0
# Equipment                  CN1
# Name: 1704, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(9741) is not present in table "airport".
#
# Skipped no reference record: index                     1705
# Airline ID                None
# Source airport ID         3832
# Destination airport ID    9741
# Stops                        0
# Equipment                  PA2
# Name: 1705, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7113) is not present in table "airport".
#
# Skipped no reference record: index                     1706
# Airline ID                None
# Source airport ID         3832
# Destination airport ID    7113
# Stops                        0
# Equipment                  PA2
# Name: 1706, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7110) is not present in table "airport".
#
# Skipped no reference record: index                     1711
# Airline ID                None
# Source airport ID         7246
# Destination airport ID    7110
# Stops                        0
# Equipment                  CN1
# Name: 1711, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7110) is not present in table "airport".
#
# Skipped no reference record: index                     1712
# Airline ID                None
# Source airport ID         7110
# Destination airport ID    3832
# Stops                        0
# Equipment                  CN1
# Name: 1712, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7112) is not present in table "airport".
#
# Skipped no reference record: index                     1713
# Airline ID                None
# Source airport ID         7112
# Destination airport ID    3832
# Stops                        0
# Equipment                  CN1
# Name: 1713, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(9741) is not present in table "airport".
#
# Skipped no reference record: index                     1714
# Airline ID                None
# Source airport ID         9741
# Destination airport ID    3832
# Stops                        0
# Equipment                  PA2
# Name: 1714, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(9741) is not present in table "airport".
#
# Skipped no reference record: index                     1715
# Airline ID                None
# Source airport ID         9741
# Destination airport ID    7115
# Stops                        0
# Equipment                  PA2
# Name: 1715, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7113) is not present in table "airport".
#
# Skipped no reference record: index                     1716
# Airline ID                None
# Source airport ID         7113
# Destination airport ID    3832
# Stops                        0
# Equipment                  PA2
# Name: 1716, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(9741) is not present in table "airport".
#
# Skipped no reference record: index                     1718
# Airline ID                None
# Source airport ID         7115
# Destination airport ID    9741
# Stops                        0
# Equipment                  PA2
# Name: 1718, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7218) is not present in table "airport".
#
# Skipped no reference record: index                     1719
# Airline ID                1173
# Source airport ID         7217
# Destination airport ID    7218
# Stops                        0
# Equipment                  CNA
# Name: 1719, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(4385) is not present in table "airport".
#
# Skipped no reference record: index                     1720
# Airline ID                1173
# Source airport ID         4385
# Destination airport ID    7094
# Stops                        0
# Equipment                  CNA
# Name: 1720, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(4385) is not present in table "airport".
#
# Skipped no reference record: index                     1721
# Airline ID                1173
# Source airport ID         3599
# Destination airport ID    4385
# Stops                        0
# Equipment                  CNA
# Name: 1721, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(8202) is not present in table "airport".
#
# Skipped no reference record: index                     1723
# Airline ID                1173
# Source airport ID         3599
# Destination airport ID    8202
# Stops                        0
# Equipment                  CNA
# Name: 1723, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7099) is not present in table "airport".
#
# Skipped no reference record: index                     1730
# Airline ID                1173
# Source airport ID         3599
# Destination airport ID    7099
# Stops                        0
# Equipment                  CNA
# Name: 1730, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(8202) is not present in table "airport".
#
# Skipped no reference record: index                     1734
# Airline ID                1173
# Source airport ID         8202
# Destination airport ID    3430
# Stops                        0
# Equipment                  CNA
# Name: 1734, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(9742) is not present in table "airport".
#
# Skipped no reference record: index                     1736
# Airline ID                1173
# Source airport ID         9742
# Destination airport ID    7217
# Stops                        0
# Equipment                  CNA
# Name: 1736, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7212) is not present in table "airport".
#
# Skipped no reference record: index                     1738
# Airline ID                1173
# Source airport ID         7094
# Destination airport ID    7212
# Stops                        0
# Equipment                  CNA
# Name: 1738, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(9742) is not present in table "airport".
#
# Skipped no reference record: index                     1742
# Airline ID                1173
# Source airport ID         7095
# Destination airport ID    9742
# Stops                        0
# Equipment                  CNA
# Name: 1742, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7216) is not present in table "airport".
#
# Skipped no reference record: index                     1743
# Airline ID                1173
# Source airport ID         7097
# Destination airport ID    7216
# Stops                        0
# Equipment                  CNA
# Name: 1743, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7212) is not present in table "airport".
#
# Skipped no reference record: index                     1745
# Airline ID                1173
# Source airport ID         7212
# Destination airport ID    3599
# Stops                        0
# Equipment                  CNA
# Name: 1745, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(8201) is not present in table "airport".
#
# Skipped no reference record: index                     1746
# Airline ID                1173
# Source airport ID         8200
# Destination airport ID    8201
# Stops                        0
# Equipment                  CNA
# Name: 1746, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7216) is not present in table "airport".
#
# Skipped no reference record: index                     1748
# Airline ID                1173
# Source airport ID         7216
# Destination airport ID    3599
# Stops                        0
# Equipment                  CNA
# Name: 1748, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7218) is not present in table "airport".
#
# Skipped no reference record: index                     1750
# Airline ID                1173
# Source airport ID         7218
# Destination airport ID    3599
# Stops                        0
# Equipment                  CNA
# Name: 1750, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(8201) is not present in table "airport".
#
# Skipped no reference record: index                     1751
# Airline ID                1173
# Source airport ID         8201
# Destination airport ID    8203
# Stops                        0
# Equipment                  CNA
# Name: 1751, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7099) is not present in table "airport".
#
# Skipped no reference record: index                     1753
# Airline ID                1173
# Source airport ID         7099
# Destination airport ID    7213
# Stops                        0
# Equipment                  CNA
# Name: 1753, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(8203) is not present in table "airport".
#
# Skipped no reference record: index                     1754
# Airline ID                1173
# Source airport ID         8203
# Destination airport ID    3599
# Stops                        0
# Equipment                  CNA
# Name: 1754, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(8492) is not present in table "airport".
#
# Skipped no reference record: index                      2109
# Airline ID                18946
# Source airport ID          8492
# Destination airport ID      813
# Stops                         0
# Equipment                   BEH
# Name: 2109, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(8492) is not present in table "airport".
#
# Skipped no reference record: index                      2110
# Airline ID                18946
# Source airport ID           813
# Destination airport ID     8492
# Stops                         0
# Equipment                   BEH
# Name: 2110, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(9742) is not present in table "airport".
#
# Skipped no reference record: index                      2552
# Airline ID                16726
# Source airport ID          7217
# Destination airport ID     9742
# Stops                         0
# Equipment                   CNA
# Name: 2552, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7218) is not present in table "airport".
#
# Skipped no reference record: index                      2553
# Airline ID                16726
# Source airport ID          7217
# Destination airport ID     7218
# Stops                         0
# Equipment                   CNA
# Name: 2553, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7219) is not present in table "airport".
#
# Skipped no reference record: index                      2571
# Airline ID                16726
# Source airport ID          6713
# Destination airport ID     7219
# Stops                         0
# Equipment                   CNC
# Name: 2571, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(4385) is not present in table "airport".
#
# Skipped no reference record: index                      2574
# Airline ID                16726
# Source airport ID          4385
# Destination airport ID     3599
# Stops                         0
# Equipment                   CNA
# Name: 2574, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7200) is not present in table "airport".
#
# Skipped no reference record: index                      2576
# Airline ID                16726
# Source airport ID          7199
# Destination airport ID     7200
# Stops                         0
# Equipment                   CNA
# Name: 2576, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7216) is not present in table "airport".
#
# Skipped no reference record: index                      2590
# Airline ID                16726
# Source airport ID          3599
# Destination airport ID     7216
# Stops                         0
# Equipment                   CNA
# Name: 2590, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7218) is not present in table "airport".
#
# Skipped no reference record: index                      2591
# Airline ID                16726
# Source airport ID          3599
# Destination airport ID     7218
# Stops                         0
# Equipment                   CNA
# Name: 2591, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7099) is not present in table "airport".
#
# Skipped no reference record: index                      2593
# Airline ID                16726
# Source airport ID          3599
# Destination airport ID     7099
# Stops                         0
# Equipment                   CNA
# Name: 2593, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7238) is not present in table "airport".
#
# Skipped no reference record: index                      2603
# Airline ID                16726
# Source airport ID          7091
# Destination airport ID     7238
# Stops                         0
# Equipment                   CNA
# Name: 2603, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7238) is not present in table "airport".
#
# Skipped no reference record: index                      2604
# Airline ID                16726
# Source airport ID          7238
# Destination airport ID     7239
# Stops                         0
# Equipment                   CNA
# Name: 2604, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7238) is not present in table "airport".
#
# Skipped no reference record: index                      2605
# Airline ID                16726
# Source airport ID          7238
# Destination airport ID     7240
# Stops                         0
# Equipment                   CNA
# Name: 2605, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7219) is not present in table "airport".
#
# Skipped no reference record: index                      2643
# Airline ID                16726
# Source airport ID          7219
# Destination airport ID     6713
# Stops                         0
# Equipment                   CNC
# Name: 2643, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7219) is not present in table "airport".
#
# Skipped no reference record: index                      2644
# Airline ID                16726
# Source airport ID          7219
# Destination airport ID     7090
# Stops                         0
# Equipment                   CNC
# Name: 2644, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(9742) is not present in table "airport".
#
# Skipped no reference record: index                      2650
# Airline ID                16726
# Source airport ID          9742
# Destination airport ID     7217
# Stops                         0
# Equipment                   CNA
# Name: 2650, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(9742) is not present in table "airport".
#
# Skipped no reference record: index                      2651
# Airline ID                16726
# Source airport ID          9742
# Destination airport ID     7095
# Stops                         0
# Equipment                   CNA
# Name: 2651, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7193) is not present in table "airport".
#
# Skipped no reference record: index                      2657
# Airline ID                16726
# Source airport ID          7207
# Destination airport ID     7193
# Stops                         0
# Equipment                   CNC
# Name: 2657, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7200) is not present in table "airport".
#
# Skipped no reference record: index                      2663
# Airline ID                16726
# Source airport ID          6718
# Destination airport ID     7200
# Stops                         0
# Equipment                   CNA
# Name: 2663, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7212) is not present in table "airport".
#
# Skipped no reference record: index                      2666
# Airline ID                16726
# Source airport ID          7094
# Destination airport ID     7212
# Stops                         0
# Equipment                   CNA
# Name: 2666, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(9742) is not present in table "airport".
#
# Skipped no reference record: index                      2674
# Airline ID                16726
# Source airport ID          7095
# Destination airport ID     9742
# Stops                         0
# Equipment                   CNA
# Name: 2674, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7216) is not present in table "airport".
#
# Skipped no reference record: index                      2678
# Airline ID                16726
# Source airport ID          5966
# Destination airport ID     7216
# Stops                         0
# Equipment                   CNA
# Name: 2678, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(8201) is not present in table "airport".
#
# Skipped no reference record: index                        2681
# Airline ID                  16726
# Source airport ID            8199
# Destination airport ID       8201
# Stops                           0
# Equipment                 CNC CNA
# Name: 2681, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7212) is not present in table "airport".
#
# Skipped no reference record: index                      2686
# Airline ID                16726
# Source airport ID          7212
# Destination airport ID     4385
# Stops                         0
# Equipment                   CNA
# Name: 2686, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7193) is not present in table "airport".
#
# Skipped no reference record: index                      2699
# Airline ID                16726
# Source airport ID          3615
# Destination airport ID     7193
# Stops                         0
# Equipment                   CNC
# Name: 2699, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(8201) is not present in table "airport".
#
# Skipped no reference record: index                      2702
# Airline ID                16726
# Source airport ID          8200
# Destination airport ID     8201
# Stops                         0
# Equipment                   CNA
# Name: 2702, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(6721) is not present in table "airport".
#
# Skipped no reference record: index                      2710
# Airline ID                16726
# Source airport ID          3693
# Destination airport ID     6721
# Stops                         0
# Equipment                   CNC
# Name: 2710, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(6721) is not present in table "airport".
#
# Skipped no reference record: index                      2714
# Airline ID                16726
# Source airport ID          6721
# Destination airport ID     3693
# Stops                         0
# Equipment                   CNC
# Name: 2714, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(6721) is not present in table "airport".
#
# Skipped no reference record: index                      2715
# Airline ID                16726
# Source airport ID          6721
# Destination airport ID     3414
# Stops                         0
# Equipment                   BE1
# Name: 2715, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(6721) is not present in table "airport".
#
# Skipped no reference record: index                      2717
# Airline ID                16726
# Source airport ID          3414
# Destination airport ID     6721
# Stops                         0
# Equipment                   BE1
# Name: 2717, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7216) is not present in table "airport".
#
# Skipped no reference record: index                      2718
# Airline ID                16726
# Source airport ID          7216
# Destination airport ID     3599
# Stops                         0
# Equipment                   CNA
# Name: 2718, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7216) is not present in table "airport".
#
# Skipped no reference record: index                      2719
# Airline ID                16726
# Source airport ID          7216
# Destination airport ID     5966
# Stops                         0
# Equipment                   CNA
# Name: 2719, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7239) is not present in table "airport".
#
# Skipped no reference record: index                      2722
# Airline ID                16726
# Source airport ID          7239
# Destination airport ID     7240
# Stops                         0
# Equipment                   CNA
# Name: 2722, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7219) is not present in table "airport".
#
# Skipped no reference record: index                      2734
# Airline ID                16726
# Source airport ID          7090
# Destination airport ID     7219
# Stops                         0
# Equipment                   CNC
# Name: 2734, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7241) is not present in table "airport".
#
# Skipped no reference record: index                      2739
# Airline ID                16726
# Source airport ID          7240
# Destination airport ID     7241
# Stops                         0
# Equipment                   CNA
# Name: 2739, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7193) is not present in table "airport".
#
# Skipped no reference record: index                        2741
# Airline ID                  16726
# Source airport ID            7191
# Destination airport ID       7193
# Stops                           0
# Equipment                 CNA CNC
# Name: 2741, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7241) is not present in table "airport".
#
# Skipped no reference record: index                      2742
# Airline ID                16726
# Source airport ID          7241
# Destination airport ID     5967
# Stops                         0
# Equipment                   CNA
# Name: 2742, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7200) is not present in table "airport".
#
# Skipped no reference record: index                      2745
# Airline ID                16726
# Source airport ID          7200
# Destination airport ID     7199
# Stops                         0
# Equipment                   CNA
# Name: 2745, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7200) is not present in table "airport".
#
# Skipped no reference record: index                      2746
# Airline ID                16726
# Source airport ID          7200
# Destination airport ID     6718
# Stops                         0
# Equipment                   CNA
# Name: 2746, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7218) is not present in table "airport".
#
# Skipped no reference record: index                      2749
# Airline ID                16726
# Source airport ID          7218
# Destination airport ID     7217
# Stops                         0
# Equipment                   CNA
# Name: 2749, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7218) is not present in table "airport".
#
# Skipped no reference record: index                      2750
# Airline ID                16726
# Source airport ID          7218
# Destination airport ID     3599
# Stops                         0
# Equipment                   CNA
# Name: 2750, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(8201) is not present in table "airport".
#
# Skipped no reference record: index                        2751
# Airline ID                  16726
# Source airport ID            8201
# Destination airport ID       8203
# Stops                           0
# Equipment                 CNC CNA
# Name: 2751, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7193) is not present in table "airport".
#
# Skipped no reference record: index                      2761
# Airline ID                16726
# Source airport ID          7193
# Destination airport ID     7207
# Stops                         0
# Equipment                   CNC
# Name: 2761, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7193) is not present in table "airport".
#
# Skipped no reference record: index                      2762
# Airline ID                16726
# Source airport ID          7193
# Destination airport ID     3615
# Stops                         0
# Equipment                   CNC
# Name: 2762, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7193) is not present in table "airport".
#
# Skipped no reference record: index                      2763
# Airline ID                16726
# Source airport ID          7193
# Destination airport ID     7191
# Stops                         0
# Equipment                   CNC
# Name: 2763, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7193) is not present in table "airport".
#
# Skipped no reference record: index                      2764
# Airline ID                16726
# Source airport ID          7193
# Destination airport ID     7088
# Stops                         0
# Equipment                   CNA
# Name: 2764, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7099) is not present in table "airport".
#
# Skipped no reference record: index                      2769
# Airline ID                16726
# Source airport ID          7099
# Destination airport ID     3599
# Stops                         0
# Equipment                   CNA
# Name: 2769, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(8203) is not present in table "airport".
#
# Skipped no reference record: index                        2770
# Airline ID                  16726
# Source airport ID            8203
# Destination airport ID       3599
# Stops                           0
# Equipment                 CNA CNC
# Name: 2770, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(8204) is not present in table "airport".
#
# Skipped no reference record: index                     2858
# Airline ID                1500
# Source airport ID         8204
# Destination airport ID    1869
# Stops                        0
# Equipment                  DHT
# Name: 2858, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(5955) is not present in table "airport".
#
# Skipped no reference record: index                     2859
# Airline ID                1500
# Source airport ID         5955
# Destination airport ID    5840
# Stops                        0
# Equipment                  DHT
# Name: 2859, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(8206) is not present in table "airport".
#
# Skipped no reference record: index                     2864
# Airline ID                1500
# Source airport ID         8206
# Destination airport ID    1869
# Stops                        0
# Equipment                  BNI
# Name: 2864, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(8207) is not present in table "airport".
#
# Skipped no reference record: index                     2866
# Airline ID                1500
# Source airport ID         8207
# Destination airport ID    1869
# Stops                        0
# Equipment                  DHT
# Name: 2866, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(8207) is not present in table "airport".
#
# Skipped no reference record: index                     2867
# Airline ID                1500
# Source airport ID         None
# Destination airport ID    8207
# Stops                        0
# Equipment                  DHT
# Name: 2867, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(5957) is not present in table "airport".
#
# Skipped no reference record: index                     2868
# Airline ID                1500
# Source airport ID         5957
# Destination airport ID    6783
# Stops                        0
# Equipment                  DHT
# Name: 2868, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(5955) is not present in table "airport".
#
# Skipped no reference record: index                     2869
# Airline ID                1500
# Source airport ID         1869
# Destination airport ID    5955
# Stops                        0
# Equipment                  DHT
# Name: 2869, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(5957) is not present in table "airport".
#
# Skipped no reference record: index                     2874
# Airline ID                1500
# Source airport ID         1869
# Destination airport ID    5957
# Stops                        0
# Equipment                  DHT
# Name: 2874, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7901) is not present in table "airport".
#
# Skipped no reference record: index                     2876
# Airline ID                1500
# Source airport ID         1869
# Destination airport ID    7901
# Stops                        0
# Equipment                  DHT
# Name: 2876, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7895) is not present in table "airport".
#
# Skipped no reference record: index                     2877
# Airline ID                1500
# Source airport ID         1869
# Destination airport ID    7895
# Stops                        0
# Equipment                  DHT
# Name: 2877, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(5958) is not present in table "airport".
#
# Skipped no reference record: index                     2878
# ...
# DETAIL:  Key (source_airport_id)=(5712) is not present in table "airport".
#
# Skipped no reference record: index                     66007
# Airline ID                 3148
# Source airport ID          5712
# Destination airport ID     2188
# Stops                         0
# Equipment                   F50
# Name: 66007, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(4264) is not present in table "airport".
#
# Skipped no reference record: index                     66226
# Airline ID                16150
# Source airport ID          4264
# Destination airport ID     1354
# Stops                         0
# Equipment                   NDE
# Name: 66226, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(4264) is not present in table "airport".
#
# Skipped no reference record: index                     66227
# Airline ID                16150
# Source airport ID          1354
# Destination airport ID     4264
# Stops                         0
# Equipment                   NDE
# Name: 66227, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7144) is not present in table "airport".
#
# Skipped no reference record: index                     66294
# Airline ID                 1266
# Source airport ID          7144
# Destination airport ID     7205
# Stops                         0
# Equipment                   DHP
# Name: 66294, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7144) is not present in table "airport".
#
# Skipped no reference record: index                     66295
# Airline ID                 1266
# Source airport ID          7144
# Destination airport ID     3808
# Stops                         0
# Equipment                   DHP
# Name: 66295, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7145) is not present in table "airport".
#
# Skipped no reference record: index                     66296
# Airline ID                 1266
# Source airport ID          7145
# Destination airport ID     7147
# Stops                         0
# Equipment                   DHP
# Name: 66296, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7145) is not present in table "airport".
#
# Skipped no reference record: index                     66297
# Airline ID                 1266
# Source airport ID          7145
# Destination airport ID     3808
# Stops                         0
# Equipment                   DHP
# Name: 66297, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7144) is not present in table "airport".
#
# Skipped no reference record: index                     66298
# Airline ID                 1266
# Source airport ID          7205
# Destination airport ID     7144
# Stops                         0
# Equipment                   DHP
# Name: 66298, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(7147) is not present in table "airport".
#
# Skipped no reference record: index                     66299
# Airline ID                 1266
# Source airport ID          7147
# Destination airport ID     7145
# Stops                         0
# Equipment                   DHP
# Name: 66299, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7144) is not present in table "airport".
#
# Skipped no reference record: index                     66300
# Airline ID                 1266
# Source airport ID          3808
# Destination airport ID     7144
# Stops                         0
# Equipment                   DHP
# Name: 66300, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(7145) is not present in table "airport".
#
# Skipped no reference record: index                     66301
# Airline ID                 1266
# Source airport ID          3808
# Destination airport ID     7145
# Stops                         0
# Equipment                   DHP
# Name: 66301, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     66657
# Airline ID                 4611
# Source airport ID          3370
# Destination airport ID     5475
# Stops                         0
# Equipment                   320
# Name: 66657, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     66709
# Airline ID                 4611
# Source airport ID          3393
# Destination airport ID     5475
# Stops                         0
# Equipment                   738
# Name: 66709, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     66813
# Airline ID                 4611
# Source airport ID          3404
# Destination airport ID     5475
# Stops                         0
# Equipment                   738
# Name: 66813, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(6428) is not present in table "airport".
#
# Skipped no reference record: index                     66922
# Airline ID                 4611
# Source airport ID          6428
# Destination airport ID     3364
# Stops                         0
# Equipment                   737
# Name: 66922, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67056
# Airline ID                 4611
# Source airport ID          5475
# Destination airport ID     3370
# Stops                         0
# Equipment                   320
# Name: 67056, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67057
# Airline ID                 4611
# Source airport ID          5475
# Destination airport ID     3393
# Stops                         0
# Equipment                   738
# Name: 67057, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67058
# Airline ID                 4611
# Source airport ID          5475
# Destination airport ID     3404
# Stops                         0
# Equipment                   738
# Name: 67058, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67059
# Airline ID                 4611
# Source airport ID          5475
# Destination airport ID     3364
# Stops                         0
# Equipment                   737
# Name: 67059, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67060
# Airline ID                 4611
# Source airport ID          5475
# Destination airport ID     4144
# Stops                         0
# Equipment                   738
# Name: 67060, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67061
# Airline ID                 4611
# Source airport ID          5475
# Destination airport ID     3374
# Stops                         0
# Equipment                   738
# Name: 67061, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67062
# Airline ID                 4611
# Source airport ID          5475
# Destination airport ID     3368
# Stops                         0
# Equipment                   320
# Name: 67062, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67063
# Airline ID                 4611
# Source airport ID          5475
# Destination airport ID     3383
# Stops                         0
# Equipment                   738
# Name: 67063, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(6428) is not present in table "airport".
#
# Skipped no reference record: index                     67096
# Airline ID                 4611
# Source airport ID          3364
# Destination airport ID     6428
# Stops                         0
# Equipment                   737
# Name: 67096, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67113
# Airline ID                 4611
# Source airport ID          3364
# Destination airport ID     5475
# Stops                         0
# Equipment                   737
# Name: 67113, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67180
# Airline ID                 4611
# Source airport ID          4144
# Destination airport ID     5475
# Stops                         0
# Equipment                   738
# Name: 67180, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67227
# Airline ID                 4611
# Source airport ID          3374
# Destination airport ID     5475
# Stops                         0
# Equipment                   738
# Name: 67227, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67278
# Airline ID                 4611
# Source airport ID          3368
# Destination airport ID     5475
# Stops                         0
# Equipment                   320
# Name: 67278, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(5475) is not present in table "airport".
#
# Skipped no reference record: index                     67383
# Airline ID                 4611
# Source airport ID          3383
# Destination airport ID     5475
# Stops                         0
# Equipment                   738
# Name: 67383, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(6129) is not present in table "airport".
#
# Skipped no reference record: index                     67528
# Airline ID                 2607
# Source airport ID          3751
# Destination airport ID     6129
# Stops                         0
# Equipment                   EM2
# Name: 67528, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(6129) is not present in table "airport".
#
# Skipped no reference record: index                     67537
# Airline ID                 2607
# Source airport ID          6129
# Destination airport ID     3751
# Stops                         0
# Equipment                   EM2
# Name: 67537, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(6132) is not present in table "airport".
#
# Skipped no reference record: index                     67542
# Airline ID                 2607
# Source airport ID          6132
# Destination airport ID     3484
# Stops                         0
# Equipment                   BE1
# Name: 67542, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(6132) is not present in table "airport".
#
# Skipped no reference record: index                     67543
# Airline ID                 2607
# Source airport ID          6132
# Destination airport ID     4124
# Stops                         0
# Equipment                   BE1
# Name: 67543, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(6132) is not present in table "airport".
#
# Skipped no reference record: index                     67544
# Airline ID                 2607
# Source airport ID          3484
# Destination airport ID     6132
# Stops                         0
# Equipment                   BE1
# Name: 67544, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(6132) is not present in table "airport".
#
# Skipped no reference record: index                     67555
# Airline ID                 2607
# Source airport ID          4124
# Destination airport ID     6132
# Stops                         0
# Equipment                   BE1
# Name: 67555, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_destination_airport_id_fkey"
# DETAIL:  Key (destination_airport_id)=(6135) is not present in table "airport".
#
# Skipped no reference record: index                     67559
# Airline ID                 2607
# Source airport ID          3462
# Destination airport ID     6135
# Stops                         0
# Equipment                   BE1
# Name: 67559, dtype: object
# Error:  insert or update on table "route" violates foreign key constraint "route_source_airport_id_fkey"
# DETAIL:  Key (source_airport_id)=(6135) is not present in table "airport".
#
# Skipped no reference record: index                     67568
# Airline ID                 2607
# Source airport ID          6135
# Destination airport ID     3462
# Stops                         0
# Equipment                   BE1
# Name: 67568, dtype: object

# %%
len(dropped_rows)
# Out:
# 476

# %%
cur.execute("""
SELECT COUNT(1)
FROM route
;
""")
results = cur.fetchone()

# %%
results
# Out:
# (67187,)
